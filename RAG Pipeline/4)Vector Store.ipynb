# %% [markdown]
# ## Vector Store Techniques

# %% [markdown]
# ## FAISS

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

loader=TextLoader("../data/Ai_and_society.txt") #load a text file
documents=loader.load() #list of documents
text_splitter=CharacterTextSplitter(chunk_size=1000, chunk_overlap=30)
docs=text_splitter.split_documents(documents)

# %%
embeddings=OllamaEmbeddings(model="mxbai-embed-large") #create embeddings with model mxbai-embed-large
db=FAISS.from_documents(docs, embeddings)
db
# Out:
# C:\Users\gauricchio\AppData\Local\Temp\ipykernel_16088\2340211842.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings=OllamaEmbeddings(model="mxbai-embed-large")

# %% [markdown]
# #### Metodo 1: Vector Store DB

# %%
#### querying 
query="How does the speaker describe the AI's role in the society?"
docs=db.similarity_search(query)
#Response
docs[0].page_content
# Out:
# 'Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'

# %% [markdown]
# - "db.similarity_search' --> search the most similar documents to the query in the FAISS database
# - "docs[0].page_content" --> print the contents of the first most similar document

# %% [markdown]
# #### Metodo 2: Retriever Class
# Possiamo anche convertire il vector store in una classe Retriever.
# Questo ci permetterà di usarlo più facilmente negli altri metodi di Langchain che utilizzano in larga scala i retrievers.

# %%
#Retriever
retriever=db.as_retriever() #converting the vector store db into a retriever object

docs=retriever.invoke(query)
docs[0].page_content
# Out:
# 'Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'

# %% [markdown]
# - "db.as_retriever()' --> converts FAISS into a retriever, making research more modular for other langchain applications
# - "retriever.invoke(query)" --> do the research with the retriever

# %% [markdown]
# #### Metodo 3: Similarity Search con punteggio (score)
# **similarity_search_with_score** is a FAISS method that returns not only the documents, but also the distance score of the query from the documents. This is an L2 distance score, so the lower the score, the better.

# %%
docs_and_score = db.similarity_search_with_score(query)
docs_and_score #we got a list of tuples (document, score)
# Out:
# [(Document(id='0df542f0-093c-4d01-a3a1-1138c3fd1758', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'),
#   np.float32(128.60834)),
#  (Document(id='f0b31b73-a619-441e-8722-6b46b2521096', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Looking ahead, AI will likely become even more integrated into everyday life, from smart homes \nthat anticipate our needs to virtual assistants capable of complex reasoning. The future of AI \noffers enormous opportunities, but it also demands careful oversight, transparency, and a constant \ncommitment to ethics and responsibility.'),
#   np.float32(135.56409)),
#  (Document(id='8e720ad5-f255-4b61-8769-fc21c8e0ce0a', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Despite these benefits, the rise of AI also raises important challenges. One major concern is the \npotential loss of jobs due to automation, which may affect millions of workers worldwide. Ethical \nquestions such as bias in algorithms, lack of transparency, and respect for privacy have become \ncentral topics of discussion. If not addressed, these issues could lead to inequalities and mistrust \ntoward AI-driven systems.\n\nGovernments, researchers, and organizations are working to establish regulations and frameworks \nthat ensure AI development remains safe, fair, and aligned with human values. International \ncollaboration is becoming crucial to create standards that protect citizens while still encouraging \ninnovation.'),
#   np.float32(156.2543))]

# %% [markdown]
# We can also pass vectors, rather than sentences

# %%
embedding_vector=embeddings.embed_query(query) #convert the query into an embedding vector
embedding_vector
# Out:
# [0.5202500820159912,
#  -0.00838441401720047,
#  -0.33865606784820557,
#  -0.24595975875854492,
#  0.3362780809402466,
#  -0.7365673780441284,
#  -0.615524172782898,
#  0.13088048994541168,
#  0.17378191649913788,
#  0.07084904611110687,
#  -0.12041620910167694,
#  0.15887565910816193,
#  -0.1867741346359253,
#  0.26649877429008484,
#  -0.4558226764202118,
#  -0.19813929498195648,
#  -0.33517390489578247,
#  -0.3104889392852783,
#  0.23106595873832703,
#  -0.514039158821106,
#  0.30982980132102966,
#  0.2622174918651581,
#  -1.050834059715271,
#  -0.5501865148544312,
#  -1.33937406539917,
#  0.37980589270591736,
#  0.026841431856155396,
#  0.26286762952804565,
#  0.9006578326225281,
#  -0.060406796634197235,
#  0.1849794089794159,
#  -0.15013396739959717,
#  -0.5107271671295166,
#  -0.9884954690933228,
#  0.24002137780189514,
#  -0.09940275549888611,
#  0.7333295941352844,
#  -1.6291735172271729,
#  -0.530634343624115,
#  -0.7067144513130188,
#  0.38213932514190674,
#  0.35081803798675537,
#  0.36913713812828064,
#  -1.6266767978668213,
#  -1.2490603923797607,
#  0.480518102645874,
#  0.022649064660072327,
#  -0.7844671607017517,
#  -0.09446215629577637,
#  -0.33511412143707275,
#  -0.1774529367685318,
#  0.360289067029953,
#  0.1881249099969864,
#  -0.05784745514392853,
#  0.040627866983413696,
#  -0.6642991304397583,
#  -0.3089044690132141,
#  0.5485869646072388,
#  -0.36348894238471985,
#  -0.3639765679836273,
#  1.2658458948135376,
#  0.0994492620229721,
#  -0.053795378655195236,
#  -0.7981967329978943,
#  0.1966947317123413,
#  0.27718180418014526,
#  -0.26750823855400085,
#  0.03512025624513626,
#  -0.7803347706794739,
#  -0.40789544582366943,
#  0.33915820717811584,
#  -0.12013234198093414,
#  -0.8634836673736572,
#  -0.3441104292869568,
#  0.8029246926307678,
#  -0.10085518658161163,
#  0.3860791325569153,
#  -0.3427000939846039,
#  0.2365294098854065,
#  -0.37997913360595703,
#  0.3429112434387207,
#  0.06465093791484833,
#  0.36156970262527466,
#  0.3314562439918518,
#  -0.5139845609664917,
#  0.8703703284263611,
#  -0.8780103325843811,
#  0.0991058275103569,
#  -0.894280195236206,
#  0.43679460883140564,
#  0.12499669194221497,
#  -0.35465264320373535,
#  -0.236863374710083,
#  -1.23866868019104,
#  -0.260790079832077,
#  -0.105434849858284,
#  -0.5483191013336182,
#  0.32086700201034546,
#  -0.38645437359809875,
#  0.05290854722261429,
#  0.3176496922969818,
#  0.4569801092147827,
#  0.4394037127494812,
#  0.08758153021335602,
#  0.19927218556404114,
#  -0.09808380156755447,
#  ...]

# %%
docs_score=db.similarity_search_by_vector(embedding_vector)
docs_score
# Out:
# [Document(id='0df542f0-093c-4d01-a3a1-1138c3fd1758', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'),
#  Document(id='f0b31b73-a619-441e-8722-6b46b2521096', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Looking ahead, AI will likely become even more integrated into everyday life, from smart homes \nthat anticipate our needs to virtual assistants capable of complex reasoning. The future of AI \noffers enormous opportunities, but it also demands careful oversight, transparency, and a constant \ncommitment to ethics and responsibility.'),
#  Document(id='8e720ad5-f255-4b61-8769-fc21c8e0ce0a', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Despite these benefits, the rise of AI also raises important challenges. One major concern is the \npotential loss of jobs due to automation, which may affect millions of workers worldwide. Ethical \nquestions such as bias in algorithms, lack of transparency, and respect for privacy have become \ncentral topics of discussion. If not addressed, these issues could lead to inequalities and mistrust \ntoward AI-driven systems.\n\nGovernments, researchers, and organizations are working to establish regulations and frameworks \nthat ensure AI development remains safe, fair, and aligned with human values. International \ncollaboration is becoming crucial to create standards that protect citizens while still encouraging \ninnovation.')]

# %% [markdown]
# ##### Salvataggio e Caricamente del VectorStore DB

# %%
db.save_local("faiss_index") #save the db locally

# %%
new_df=FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True) #load the db locally

# %%
docs=new_df.similarity_search(query) #search with new db loaded
docs
# Out:
# [Document(id='0df542f0-093c-4d01-a3a1-1138c3fd1758', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'),
#  Document(id='f0b31b73-a619-441e-8722-6b46b2521096', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Looking ahead, AI will likely become even more integrated into everyday life, from smart homes \nthat anticipate our needs to virtual assistants capable of complex reasoning. The future of AI \noffers enormous opportunities, but it also demands careful oversight, transparency, and a constant \ncommitment to ethics and responsibility.'),
#  Document(id='8e720ad5-f255-4b61-8769-fc21c8e0ce0a', metadata={'source': '../data/Ai_and_society.txt'}, page_content='Despite these benefits, the rise of AI also raises important challenges. One major concern is the \npotential loss of jobs due to automation, which may affect millions of workers worldwide. Ethical \nquestions such as bias in algorithms, lack of transparency, and respect for privacy have become \ncentral topics of discussion. If not addressed, these issues could lead to inequalities and mistrust \ntoward AI-driven systems.\n\nGovernments, researchers, and organizations are working to establish regulations and frameworks \nthat ensure AI development remains safe, fair, and aligned with human values. International \ncollaboration is becoming crucial to create standards that protect citizens while still encouraging \ninnovation.')]

# %% [markdown]
# ## Chroma DB

# %%
##Costruzione di a sample vector db
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader=TextLoader("../data/AI_and_society.txt") #caricamento
data=loader.load()
data
# Out:
# [Document(metadata={'source': '../data/AI_and_society.txt'}, page_content='Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.\n\nIn healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.\n\nDespite these benefits, the rise of AI also raises important challenges. One major concern is the \npotential loss of jobs due to automation, which may affect millions of workers worldwide. Ethical \nquestions such as bias in algorithms, lack of transparency, and respect for privacy have become \ncentral topics of discussion. If not addressed, these issues could lead to inequalities and mistrust \ntoward AI-driven systems.\n\nGovernments, researchers, and organizations are working to establish regulations and frameworks \nthat ensure AI development remains safe, fair, and aligned with human values. International \ncollaboration is becoming crucial to create standards that protect citizens while still encouraging \ninnovation. \n\nLooking ahead, AI will likely become even more integrated into everyday life, from smart homes \nthat anticipate our needs to virtual assistants capable of complex reasoning. The future of AI \noffers enormous opportunities, but it also demands careful oversight, transparency, and a constant \ncommitment to ethics and responsibility.\n')]

# %%
#Split
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
splits=text_splitter.split_documents(data)

# %%
#Creazione Vector Store
embedding=OllamaEmbeddings(model="mxbai-embed-large")
vectordb=Chroma.from_documents(documents=splits, embedding=embedding)
vectordb

# %%
#query it
query = "Can AI have an impact on heathcare?"
docs= vectordb.similarity_search(query)
docs[0].page_content
# Out:
# 'In healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'

# %%
#Saving to the disk
vectordb=Chroma.from_documents(documents=splits, embedding=embedding, persist_directory="./chroma_db")

# %%
#Load from disk
db2 = Chroma(persist_directory="./chroma_db", embedding_function=embedding)
docs=db2.similarity_search(query) #we make the same query as before
print(docs[0].page_content)
# Out:
# In healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before.
# In finance, machine learning models can identify fraudulent transactions within seconds and provide
# personalized investment advice. In transportation, autonomous vehicles are being tested to reduce
# accidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons
# to the pace and needs of each student.

# %%
#Similarity Search con Similarity Score
docs=vectordb.similarity_search_with_score(query)
docs
# Out:
# [(Document(id='6dc23af7-a858-48df-aca3-5db8724b5fbc', metadata={'source': '../data/AI_and_society.txt'}, page_content='In healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before. \nIn finance, machine learning models can identify fraudulent transactions within seconds and provide \npersonalized investment advice. In transportation, autonomous vehicles are being tested to reduce \naccidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons \nto the pace and needs of each student.'),
#   194.36978149414062),
#  (Document(id='95170424-c4d8-4c82-9eda-938fd907c499', metadata={'source': '../data/AI_and_society.txt'}, page_content='Artificial Intelligence and Society\n\nArtificial Intelligence (AI) is rapidly transforming the way we live, work, and interact with technology. \nToday, AI systems are able to recognize speech, translate languages, diagnose diseases, and even create art. \nThese capabilities open new possibilities for innovation across industries, including healthcare, finance, \ntransportation, and education.'),
#   201.8792724609375),
#  (Document(id='8542b072-289b-4a95-b780-a80b61cffef3', metadata={'source': '../data/AI_and_society.txt'}, page_content='Looking ahead, AI will likely become even more integrated into everyday life, from smart homes \nthat anticipate our needs to virtual assistants capable of complex reasoning. The future of AI \noffers enormous opportunities, but it also demands careful oversight, transparency, and a constant \ncommitment to ethics and responsibility.'),
#   211.7076416015625),
#  (Document(id='533b8c1d-bec3-4aca-b713-3a1e73fd732e', metadata={'source': '../data/AI_and_society.txt'}, page_content='Despite these benefits, the rise of AI also raises important challenges. One major concern is the \npotential loss of jobs due to automation, which may affect millions of workers worldwide. Ethical \nquestions such as bias in algorithms, lack of transparency, and respect for privacy have become \ncentral topics of discussion. If not addressed, these issues could lead to inequalities and mistrust \ntoward AI-driven systems.'),
#   229.8397979736328)]

# %% [markdown]
# Using as Retriever: The same of FAISS. It converts the vector store into a retrieevr for a more efficient search in the Langchain flow

# %%
#Retriever Option
retriever=vectordb.as_retriever()
print(retriever.invoke(query)[0].page_content)
# Out:
# In healthcare, AI helps doctors analyze medical images and detect illnesses earlier than ever before.
# In finance, machine learning models can identify fraudulent transactions within seconds and provide
# personalized investment advice. In transportation, autonomous vehicles are being tested to reduce
# accidents and make travel more efficient. In education, intelligent tutoring systems adapt lessons
# to the pace and needs of each student.
